# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# iterate over V, E=1, L=[10,0], E=1, s1=500, s2=2
# V, z, phi, Jx1, Jy1, times
d1=np.load("/rhome/mlamb005/spincode/results/Vvar_zpxyt.npy", allow_pickle=True)

# %%
V     = d1[0]
z_t   = d1[1]
phi_t = d1[2]
Jx_1  = d1[3]
Jy_1  = d1[4]
times = d1[5]
#print(np.shape(d1))
#print(len(z_t))

# %%
# plot stuff, for loops
for i in range(len(z_t)):
    plt.plot(times, z_t[i], label=V[i])
plt.ylabel('z_t')
plt.xlabel('time')
plt.legend()

# %%
for i in range(len(z_t)):
    plt.plot(times, Jy_1[i], label=V[i])
plt.ylabel('Jy_1')
plt.xlabel('time')
plt.legend()

# %%
# take time averages of z, etc and plot those
z_avg = []
for i in range(len(z_t)):
    z_avg.append(np.average([z_t[i][100:]]))
print(z_avg)
# Out:
# [0.1674987228629311, 0.16779788873034998, 0.16875917260268838, 0.1618394495753518, 0.16328686603360174, 0.16906024868543593, 0.16765873197337872, 0.16473194454361062, 0.16703816402263394, 0.16829689739238443, 0.17168610380765717, 0.17422957846242404, 0.1773246703801464, 0.17969555167790058, 0.18386119541657556, 0.18876134731078006, 0.19554838948887285, 0.1983206731216515, 0.20150238226544712, 0.20363052290675238]

# %%
plt.plot(z_avg, V)
plt.ylabel('V')
plt.xlabel('<z(t)>')
# Out:
# Text(0.5, 0, '<z(t)>')
