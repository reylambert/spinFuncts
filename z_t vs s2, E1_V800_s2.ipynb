# %%
# import, work w/ code from cluster
# <z(t)> vs S2

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

import spinFuncts as sf

# %%
df  = pd.read_csv("E1V800s100s2.csv")
d   = df.values
# 4x21 array: s2, z(t) x21, phi(t) x21, Jx_1(t) x21
raw = d.T

#print(raw[0][20])
s2    = raw[0]
z     = raw[1]
phi   = raw[2]
Jx_1  = raw[3]

# why are your sublists all strings!! you are lists!!
# did adding s2 list to csv break the other ones??

times = np.linspace(0.0, 100, 1000)

#print(type(phi_t[1]))
#print(z[0])

#print(z[0].split())
zi = z[0].split()
z_test = np.array(map(float, zi))

print(z_test[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-126-c57f72190dc0> in <module>
#      22 z_test = np.array(map(float, zi))
#      23
# ---> 24 print(z_test[0])
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed

# %%
z_t=[]
for i in range(len(s2)):
    z_t.append(np.array(z_t[i]))
print(type(z_t))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-60-876cb83c86ca> in <module>
#       1 z_t=[]
#       2 for i in range(len(s2)):
# ----> 3     z_t.append(np.array(z_t[i]))
#       4 print(type(z_t))
#
# IndexError: list index out of range

# %%
for i in range(len(s2)):
    plt.plot(times, z_t[i], label=s2[i])

plt.ylabel('z')
plt.xlabel('time')
plt.legend()
print("E =", E, ", |J1|=", S1, ", |J2|=", S2[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-e3658ee23133> in <module>
#       1 for i in range(len(s2)):
# ----> 2     plt.plot(times, z_t[i], label=s2[i])
#       3
#       4 plt.ylabel('z')
#       5 plt.xlabel('time')
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2824     return gca().plot(
#    2825         *args, scalex=scalex, scaley=scaley,
# -> 2826         **({"data": data} if data is not None else {}), **kwargs)
#    2827
#    2828
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
# ...

# %%
steps = 1000
tf    = 50

def slice_avg(i, f, vect, t_t=tf):
    dt = tf/steps
    a  = int(i/dt)
    b  = int(f/dt)
    return sum(vect[a:b])/(f-i)

z_avg = []

for i in range(len(s2)):
    z_avg.append(slice_avg(40, 80, z_t[i]))
    
print(z_avg)
# Out:
# [(1.0323209086601872+2.63882783075282e-19j), (1.0356561854008774+9.01290408140924e-20j), (0.9615560101594474-8.461017427551237e-20j)]

# %%
plt.plot(s2, z_avg)
plt.ylabel('<z(t)>')
plt.xlabel('|J2|')
print("E =", E, ", |J1|=", S1, ", |J2|=", S2)
# Out:
# E = 1 , |J1|= 50 , |J2|= ['1/2', '2', '5']

# %%
plt.plot(times, Jx_1[0], label=phis[0])

plt.ylabel('z')
plt.xlabel('time')
plt.legend()
# Out:
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
for i in range(len(phis)):
    plt.plot(phi_t[i], z_t[i], label=phis[i])

plt.ylabel('z')
plt.xlabel('phi')
plt.legend()
print("E =", E, ", |J1|=", S1, ", |J2|=", S2[0])
# Out:
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# ...

# %%
for i in range(len(V)):
    plt.plot(times, Jz_1[i], label=i)

plt.ylabel('Jz_1')
plt.xlabel('time')
plt.legend()
print("E =", E, ", L =", L)
# Out:
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# ...

# %%
for i in range(len(V)):
    plt.plot(times, Jx_1[i], label=i)

plt.ylabel('Jx_1')
plt.xlabel('time')
plt.legend()
print("E =", E, ", L =", L)
# Out:
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# ...
