# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# iterate over s2, E=0.5, V=800, L=[10,0], s1=100
# s2, z, phi, Jx1, Jy1, times
d1=np.load("/rhome/mlamb005/spincode/results/E3V800_s2var_zpxyt.npy", allow_pickle=True)

# %%
s2    = d1[0]
z_t   = d1[1]
phi_t = d1[2]
Jx_1  = d1[3]
Jy_1  = d1[4]
times = d1[5]
#print(np.shape(d1))
#print(len(z_t))

# %%
# plot stuff, for loops
for i in range(len(z_t)):
    plt.plot(times, z_t[i], label=s2[i])
plt.ylabel('z_t')
plt.xlabel('time')
plt.legend()

# %%
# take time averages of z, etc and plot those
z_avg = []
for i in range(len(z_t)):
    z_avg.append(np.average([z_t[i][200:]]))
print(z_avg)
# Out:
# [0.39288250977498973, 0.6433949417360317, 0.6014201672561542, 0.5857011913941003, 0.5928170584483867, 0.6131388898544465, 0.6282799562671566, 0.6409844786389766, 0.6494291665644834, 0.6594464300696078, 0.6662618922627418, 0.6743755905381428, 0.6780121314420707, 0.6857010804236934, 0.6903476734247029, 0.6956031020564772, 0.6995888854783755, 0.7035270322207805, 0.707825287802242, 0.7107534163173678, 0.7141884684241694]

# %%
plt.plot(z_avg, s2)
plt.ylabel('s2, |J2|')
plt.xlabel('<z(t)>')
# Out:
# Text(0.5, 0, '<z(t)>')
