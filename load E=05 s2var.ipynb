# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# iterate over s2, E=0.5, V=800, L=[10,0], s1=100
# s2, z, phi, Jx1, Jy1, times
d1=np.load("/rhome/mlamb005/spincode/results/E05V800_s2var_zpxyt.npy", allow_pickle=True)

# %%
s2    = d1[0]
z_t   = d1[1]
phi_t = d1[2]
Jx_1  = d1[3]
Jy_1  = d1[4]
times = d1[5]
#print(np.shape(d1))
#print(len(z_t))

# %%
# plot stuff, for loops
for i in range(len(z_t)):
    plt.plot(times, z_t[i], label=s2[i])
plt.ylabel('z_t')
plt.xlabel('time')
plt.legend()

# %%
# take time averages of z, etc and plot those
z_avg = []
for i in range(len(z_t)):
    z_avg.append(np.average([z_t[i][200:]]))
print(z_avg)
# Out:
# [0.38103931518353384, 0.20364358341562044, 0.27065265421559537, 0.30901894594597507, 0.3345380216229609, 0.3526365378351617, 0.36637902746961715, 0.37707341214791484, 0.3847284769292183, 0.39217502970603346, 0.3965659942002292, 0.4023084524469246, 0.40588983605572837, 0.4089971470574736, 0.41264267126648235, 0.416792761312875, 0.4189939783871431, 0.4212184863905905, 0.41864514866660874, 0.42231158263614077, 0.4243803088111025]

# %%
plt.plot(z_avg, s2)
plt.ylabel('s2, |J2|')
plt.xlabel('<z(t)>')
# Out:
# Text(0.5, 0, '<z(t)>')
