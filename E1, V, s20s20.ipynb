# %%
# play with new stuff, coupling, s2
# less time consuming runs (less evolved systems, only around nontherm. parameters)
# try to break the nonthermalizing states

# %%
from quspin.operators import hamiltonian
from quspin.basis import spin_basis_general, tensor_basis
from quspin.tools.measurements import obs_vs_time
import numpy as np
from matplotlib import pyplot as plt
from scipy import optimize

import spinFuncts as sf

# %%
E = 1

N  = 1        #system size
V  = 50        #coupling strength
L  = [10, 0]   #lambda prefix, Jzz_i

S1 = '20'    #spin of 1
S2 = '20'    #spin of 2

s1 = 20
s2 = 20

z2   = 0
phi2 = 0

# %%
tf = s1

phis = [0, np.pi/8, np.pi/4, 3*np.pi/8, np.pi/2, 5*np.pi/8, 3*np.pi/4, 7*np.pi/8, np.pi]
zs   = sf.getZs_Ec(phis, L[0], E)
times = np.linspace(0.0, 50, 1000)

print(zs)
# Out:
# [0.5999999999999974, 0.5908272571395902, 0.5629260834287482, 0.5153544317138572, 0.44721359549995787, 0.3585414136979034, 0.25122544575639594, 0.1295415632033619, 0.0]

# %%
z_t   = []
phi_t = []

Jx_1 = []
Jy_1 = []
Jz_1 = []

for i in range(len(phis)):
    zi, phii, J1_i, J2_i = sf.evolveSys_all(zs[i], phis[i], 0, 0, times, S1, s1, S2, s2, L, V, N)
    z_t.append(zi[0])
    phi_t.append(phii[0])
    Jx_1.append(J1_i[0])
    Jy_1.append(J1_i[1])
    Jz_1.append(J1_i[2])
# Out:
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# dict_keys(['Jx_1', 'Jy_1', 'Jz_1', 'Jx_2', 'Jy_2', 'Jz_2', 'psi_t'])
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# dict_keys(['Jx_1', 'Jy_1', 'Jz_1', 'Jx_2', 'Jy_2', 'Jz_2', 'psi_t'])
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# dict_keys(['Jx_1', 'Jy_1', 'Jz_1', 'Jx_2', 'Jy_2', 'Jz_2', 'psi_t'])
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# dict_keys(['Jx_1', 'Jy_1', 'Jz_1', 'Jx_2', 'Jy_2', 'Jz_2', 'psi_t'])
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# dict_keys(['Jx_1', 'Jy_1', 'Jz_1', 'Jx_2', 'Jy_2', 'Jz_2', 'psi_t'])
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# dict_keys(['Jx_1', 'Jy_1', 'Jz_1', 'Jx_2', 'Jy_2', 'Jz_2', 'psi_t'])
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# dict_keys(['Jx_1', 'Jy_1', 'Jz_1', 'Jx_2', 'Jy_2', 'Jz_2', 'psi_t'])
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# dict_keys(['Jx_1', 'Jy_1', 'Jz_1', 'Jx_2', 'Jy_2', 'Jz_2', 'psi_t'])
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# Hermiticity check passed!
# dict_keys(['Jx_1', 'Jy_1', 'Jz_1', 'Jx_2', 'Jy_2', 'Jz_2', 'psi_t'])

# %%
for i in range(len(phis)):
    plt.plot(phi_t[i], z_t[i], label=i)

plt.ylabel('z')
plt.xlabel('phi')
plt.legend()
print("E =", E, ", L =", L)
# Out:
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# E = 1 , L = [10, 0]

# %%
for i in range(len(phis)):
    plt.plot(times, z_t[i], label=i)

plt.ylabel('z')
plt.xlabel('time')
plt.legend()
print("E =", E, ", L =", L)
# Out:
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# E = 1 , L = [10, 0]

# %%
for i in range(len(phis)):
    plt.plot(times, Jz_1[i], label=i)

plt.ylabel('Jz_1')
plt.xlabel('time')
plt.legend()
print("E =", E, ", L =", L)
# Out:
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# E = 1 , L = [10, 0]

# %%
for i in range(len(phis)):
    plt.plot(times, Jx_1[i], label=i)

plt.ylabel('Jx_1')
plt.xlabel('time')
plt.legend()
print("E =", E, ", L =", L)
# Out:
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Rey\AppData\Roaming\Python\Python36\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# E = 1 , L = [10, 0]

# %%
for i in range(len(phis)):
    print(sum(z_t[i][250:500]/250))
# Out:
# (0.10250185029353664-1.9409046127045746e-20j)
# (0.09272978966272388-2.4981815631509887e-21j)
# (0.08569633422742579+1.69414304839044e-20j)
# (0.06742355206687921+1.9358106020954248e-20j)
# (0.043394299132185676+1.831630806330191e-20j)
# (0.03409596920635011+4.44958424613116e-20j)
# (0.018053389230085135-8.159965424909986e-20j)
# (0.00724553046957277+2.5024697213849118e-20j)
# (5.015411383216423e-17-1.7563656827858886e-20j)

# %%
for i in range(len(phis)):
    print(sum(Jz_1[i][250:500]/250))
# Out:
# (2.050037005870733-3.8818092254091496e-19j)
# (1.8545957932544783-4.9963631263019766e-20j)
# (1.713926684548516+3.388286096780873e-19j)
# (1.3484710413375853+3.8716212041908477e-19j)
# (0.8678859826437135+3.6632616126603814e-19j)
# (0.6819193841270021+8.899168492262321e-19j)
# (0.36106778460170286-1.6319930849819962e-18j)
# (0.14491060939145534+5.004939442769822e-19j)
# (1.003082276643284e-15-3.5127313655717803e-19j)

# %%
for i in range(len(phis)):
    print(sum(Jx_1[i][250:500]/250))
# Out:
# (1.2687880807219967+1.7111561771298e-19j)
# (1.1955665639865631+2.0929943714203077e-18j)
# (0.9523293826323949+2.8282077365058738e-18j)
# (0.5858809566493242+1.491947440579637e-18j)
# (0.32368073003564035+2.339497675537104e-18j)
# (0.2622012029885975-7.850175830746139e-19j)
# (-0.33883921613628054-3.711997748263228e-18j)
# (-0.9294393623213913+6.521371442289819e-18j)
# (-1.5334346834176245-9.934721093207248e-19j)
